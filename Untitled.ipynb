# %%
# Draw the heatmap of different K values

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_theme()


# Load the example  dataset and convert to long-form
data_df = pd.read_csv('data/virtual1.csv')
data_df
flights = data_df.pivot("ki", "kd", "time")
data_df = data_df#.loc[data_df['ki'] <= 0.16]#.loc[data_df['ki'] <= 20]
data_pivot2 = data_df.pivot("ki", "kd", "time")
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(data_pivot2, annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:xlabel='kd', ylabel='ki'>

# %%
data_df[data_df['kd'] <= 1.7 ]
# Out:
#    Unnamed: 0  ki   kd       time
# 0   (10, 0.0)  10  0.0  10.908095
# 1   (10, 0.5)  10  0.5  11.912831
# 2   (10, 1.0)  10  1.0  12.161783
# 3   (10, 1.5)  10  1.5  12.282197
# 4   (11, 0.0)  11  0.0  11.952348
# 5   (11, 0.5)  11  0.5  11.784680
# 6   (11, 1.0)  11  1.0  12.077728
# 7   (11, 1.5)  11  1.5  11.970460
# 8   (12, 0.0)  12  0.0  11.781821
# 9   (12, 0.5)  12  0.5  11.553058
# 10  (12, 1.0)  12  1.0  11.721236
# 11  (12, 1.5)  12  1.5  11.141889
# 12  (13, 0.0)  13  0.0  13.874141
# 13  (13, 0.5)  13  0.5  11.103194
# 14  (13, 1.0)  13  1.0  11.664098
# 15  (13, 1.5)  13  1.5  11.159100
# 16  (14, 0.0)  14  0.0  11.650819
# 17  (14, 0.5)  14  0.5  11.093534
# 18  (14, 1.0)  14  1.0  13.913876
# 19  (14, 1.5)  14  1.5  10.941092
# 20  (15, 0.0)  15  0.0  13.619346
# 21  (15, 0.5)  15  0.5  10.980894
# 22  (15, 1.0)  15  1.0  13.377692
# 23  (15, 1.5)  15  1.5  11.015982
# 24  (16, 0.0)  16  0.0  13.642472
# 25  (16, 0.5)  16  0.5  12.964227
# ...

# %%
data_df
# Out:
#    Unnamed: 0  ki   kd       time
# 0   (10, 0.0)  10  0.0  10.908095
# 1   (10, 0.5)  10  0.5  11.912831
# 2   (10, 1.0)  10  1.0  12.161783
# 3   (10, 1.5)  10  1.5  12.282197
# 4   (11, 0.0)  11  0.0  11.952348
# 5   (11, 0.5)  11  0.5  11.784680
# 6   (11, 1.0)  11  1.0  12.077728
# 7   (11, 1.5)  11  1.5  11.970460
# 8   (12, 0.0)  12  0.0  11.781821
# 9   (12, 0.5)  12  0.5  11.553058
# 10  (12, 1.0)  12  1.0  11.721236
# 11  (12, 1.5)  12  1.5  11.141889
# 12  (13, 0.0)  13  0.0  13.874141
# 13  (13, 0.5)  13  0.5  11.103194
# 14  (13, 1.0)  13  1.0  11.664098
# 15  (13, 1.5)  13  1.5  11.159100
# 16  (14, 0.0)  14  0.0  11.650819
# 17  (14, 0.5)  14  0.5  11.093534
# 18  (14, 1.0)  14  1.0  13.913876
# 19  (14, 1.5)  14  1.5  10.941092
# 20  (15, 0.0)  15  0.0  13.619346
# 21  (15, 0.5)  15  0.5  10.980894
# 22  (15, 1.0)  15  1.0  13.377692
# 23  (15, 1.5)  15  1.5  11.015982
# 24  (16, 0.0)  16  0.0  13.642472
# 25  (16, 0.5)  16  0.5  12.964227
# ...
